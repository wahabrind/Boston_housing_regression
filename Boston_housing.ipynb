# %%
#importing dataset
from tensorflow.keras.datasets import boston_housing
(train_data, train_targets), (test_data, test_targets) =boston_housing.load_data()
print(train_data.shape)
print(test_data.shape)
print(train_targets.shape)
print(test_targets.shape)


print(train_data[0])
print(test_data[0])
print(train_targets[0])
print(test_targets[0])
# Out:
# (404, 13)
# (102, 13)
# (404,)
# (102,)
# [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]
# [ 18.0846   0.      18.1      0.       0.679    6.434  100.       1.8347
#   24.     666.      20.2     27.25    29.05  ]
# 15.2
# 7.2

# %%
#It would be problematic to feed into a neural network values that all take wildly different ranges.so we have to bring them on same levels

#normalizing data
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= std

print(train_data[0])
print(test_data[0])
# Out:
# [-0.27224633 -0.48361547 -0.43576161 -0.25683275 -0.1652266  -0.1764426
#   0.81306188  0.1166983  -0.62624905 -0.59517003  1.14850044  0.44807713
#   0.8252202 ]
# [ 1.55369355 -0.48361547  1.0283258  -0.25683275  1.03838067  0.23545815
#   1.11048828 -0.93976936  1.67588577  1.5652875   0.78447637 -3.48459553
#   2.25092074]

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu',
input_shape=(train_data.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.fit(train_data,train_targets,batch_size=32,epochs=50)
# Out:
# Epoch 1/50
# 404/404 [==============================] - 0s 331us/sample - loss: 551.4578 - mean_absolute_error: 21.5218
# Epoch 2/50
# 404/404 [==============================] - 0s 69us/sample - loss: 492.2254 - mean_absolute_error: 20.0377
# Epoch 3/50
# 404/404 [==============================] - 0s 79us/sample - loss: 415.0016 - mean_absolute_error: 17.9830
# Epoch 4/50
# 404/404 [==============================] - 0s 69us/sample - loss: 315.0080 - mean_absolute_error: 15.2160
# Epoch 5/50
# 404/404 [==============================] - 0s 79us/sample - loss: 200.5317 - mean_absolute_error: 11.7540
# Epoch 6/50
# 404/404 [==============================] - 0s 79us/sample - loss: 109.3257 - mean_absolute_error: 8.1555
# Epoch 7/50
# 404/404 [==============================] - 0s 69us/sample - loss: 65.8283 - mean_absolute_error: 6.0508
# Epoch 8/50
# 404/404 [==============================] - 0s 79us/sample - loss: 48.8657 - mean_absolute_error: 5.0445
# Epoch 9/50
# ...

# %%
y_pred=model.predict(test_data)

# %%
for i in range (len(test_targets)):
    print("predicted : {0:.2f}  ,  actual : {1}".format(y_pred[i][0],test_targets[i]))
# Out:
# predicted : 8.01  ,  actual : 7.2
# predicted : 17.29  ,  actual : 18.8
# predicted : 21.20  ,  actual : 19.0
# predicted : 34.47  ,  actual : 27.0
# predicted : 25.75  ,  actual : 22.2
# predicted : 18.03  ,  actual : 24.5
# predicted : 25.61  ,  actual : 31.2
# predicted : 22.14  ,  actual : 22.9
# predicted : 19.64  ,  actual : 20.5
# predicted : 22.42  ,  actual : 23.2
# predicted : 19.47  ,  actual : 18.6
# predicted : 17.11  ,  actual : 14.5
# predicted : 15.83  ,  actual : 17.8
# predicted : 40.43  ,  actual : 50.0
# predicted : 18.72  ,  actual : 20.8
# predicted : 19.22  ,  actual : 24.3
# predicted : 27.47  ,  actual : 24.2
# predicted : 19.90  ,  actual : 19.8
# predicted : 19.42  ,  actual : 19.1
# predicted : 28.96  ,  actual : 22.7
# predicted : 10.72  ,  actual : 12.0
# predicted : 15.74  ,  actual : 10.2
# predicted : 20.53  ,  actual : 20.0
# predicted : 14.14  ,  actual : 18.5
# predicted : 21.23  ,  actual : 20.9
# predicted : 25.04  ,  actual : 23.0
# ...
